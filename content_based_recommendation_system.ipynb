# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('/content/data.csv')
df.head()
# Out:
#    id                                               slug  \
# 0   0  https://www.mega.pk/mobiles_products/23522/Not...
# 1   1  https://www.mega.pk/mobiles_products/23458/Opp...
# 2   2  https://www.mega.pk/mobiles_products/24393/Tec...
# 3   3  https://www.mega.pk/mobiles_products/24259/Viv...
# 4   4  https://www.mega.pk/mobiles_products/24204/App...
#
#                                                title  \
# 0  Nothing Phone 1 8GB RAM 256GB Storage Non PTA ...
# 1  Oppo F21 Pro 8GB Ram 128GB Storage 5G PTA Appr...
# 2                                    Tecno Spark 10
# 3                                       Vivo V27 5G
# 4                           Apple Iphone 15 Pro Max
#
#                                                 imgs  brand category   vendor  \
# 0  ['https://www.mega.pk/items_images/Nothing+Pho...    NaN   Mobile  MEGA.PK
# 1  ['https://www.mega.pk/items_images/Oppo+F21+Pr...   OPPO   Mobile  MEGA.PK
# 2  ['https://www.mega.pk/items_images/Tecno+Spark...  Tecno   Mobile  MEGA.PK
# 3  ['https://www.mega.pk/items_images/Vivo+V27+5G...   Vivo   Mobile  MEGA.PK
# 4  ['https://www.mega.pk/items_images/Apple+Iphon...  Apple   Mobile  MEGA.PK
#
#    used                                            address availability  ...  \
# 0     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...          NaN  ...
# 1     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...          NaN  ...
# 2     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
# 3     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
# 4     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
#
#   discounted_price                                     specifications  \
# 0              NaN  {'RAM': '8GB', 'Memory quantity': '', 'Interna...
# 1              NaN  {'RAM': '8gb', 'Memory quantity': '', 'Interna...
# 2              NaN  {'RAM': '4GB,8GB', 'Memory quantity': '', 'Int...
# 3              NaN  {'RAM': '8GB,12GB', 'Memory quantity': '', 'In...
# 4              NaN  {'RAM': '8GB', 'Memory quantity': '', 'Interna...
#
#    description delivery_fee delivery_details  warranty  warranty_type  \
# 0          NaN          NaN              NaN       NaN            NaN
# 1          NaN          NaN              NaN       NaN            NaN
# 2          NaN          NaN              NaN    1 year            NaN
# 3          NaN          NaN              NaN    1 year            NaN
# 4          NaN          NaN              NaN       NaN            NaN
#
#   average_rating num_ratings  reviews
# 0            NaN         NaN       []
# 1            NaN         NaN       []
# 2            NaN         NaN       []
# 3            NaN         NaN       []
# 4            NaN         NaN       []
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# id                     0
# slug                   0
# title                  0
# imgs                   0
# brand                893
# category               0
# vendor                 0
# used                   0
# address             1122
# availability         587
# currency               0
# original_price        17
# discounted_price     927
# specifications         0
# description         1367
# delivery_fee        1559
# delivery_details    1666
# warranty            1166
# warranty_type       1277
# average_rating       766
# num_ratings          766
# reviews                0
# dtype: int64

# %%
df['specifications'][0]
# Out:
# "{'RAM': '8GB', 'Memory quantity': '', 'Internal storage space': '256GB', 'Main Camera Pixels': '50 MP, f/1.9, 24mm (wide), 1/1.56', 'Battery capacity': 'Li-Po 4500 mAh, non-removable', 'Screen size': '6.55 Inches', '5G Support': 'Yes', 'Finger Print': 'Yes', 'Display technology': 'OLED, 1B colors, 120Hz, HDR10+, 500 nits (typ), 700 nits (peak)', 'Display': '6.55 inches OLED, 1B colors', 'Number of colours': '1B', 'Scratch resistant display': '', 'Screen resolution': '1080 x 2400 pixels', 'Pixel density': '402 PPI', 'Dual screens': '', 'SD Card': 'Yes', 'SDIO': '', 'Compatible memory cards': '128GB 8GB RAM, 256GB 8GB RAM, 256GB 12GB RAM', 'Maximum amount of memory': '', 'Built-in camera': 'Yes', 'Auto focus': 'Yes', 'Built-in flash': 'Yes', 'Digital zoom (still image)': 'Yes', 'Maximum resolution (still)': '1080p 30fps', 'Number of cameras': '3', 'Front Camera Resolution': '16 MP, f/2.5, (wide), 1/3.1', 'Optical zoom': 'Yes', 'Video recorder': 'Yes', 'Digital zoom (video)': 'Yes', 'Maximum numbers of fps when recording': '30fps', 'Maximum resolution (video)': '4K 30fps', 'Graphics processor': 'Yes', 'Graphics processor type': '', 'Processor core type': 'Octa-core', 'Processor speed': '1x2.5 GHz Cortex-A78 & 3x2.4 GHz Cortex-A78', 'Chipset': 'Qualcomm SM7325-AE Snapdragon 778G+ 5G (6 nm)', 'CPU type': 'Octa-core (1x2.5 GHz Cortex-A78 & 3x2.4 GHz Cortex-A78 & 4x1.9 GHz Cortex-A55)', '4G LTE': 'Yes', 'Bluetooth': 'Yes', 'NFC Support': 'Yes', 'WiFi (Wireless Fidelity)': 'Yes', 'Colour': 'White, Black', 'Features (detail)': 'Fingerprint (under display, optical), accelerometer, proximity, gyro, compass', 'Shock resistant': '', 'Dual SIM card support': 'Yes', 'Voice dialing': 'Yes', 'Water resistant': '', '3.5mm headphone output': '', 'Type of connection': '', 'Dimensions (WxHxD)': '159.2 x 75.8 x 8.3 mm (6.27 x 2.98 x 0.33 in)', 'Weight': '193.5 g (6.84 oz)', 'Operating System': 'Android 12, Nothing OS 1.1.3', 'Release year': '2022', 'PTA Approved': 'No', 'Warranty': '', 'Price': '129,999 - PKR\\xa0Price in Pakistani Rupees'}"

# %%
def clean_text(row):
  title = row['title'] if pd.notna(row['title']) else ""
  brand = row['brand'] if pd.notna(row['brand']) else ""
  category = row['category'] if pd.notna(row['category']) else ""
  spec = ' '.join([f"{k}:{v}" for k,v in eval(row['specifications']).items() if v]) if pd.notna(row['specifications']) else ""
  return f"{title} {brand} {category} {spec}"

# %%
df['clean_text'] = df.apply(clean_text , axis = 1)

# %%
df.head()
# Out:
#    id                                               slug  \
# 0   0  https://www.mega.pk/mobiles_products/23522/Not...
# 1   1  https://www.mega.pk/mobiles_products/23458/Opp...
# 2   2  https://www.mega.pk/mobiles_products/24393/Tec...
# 3   3  https://www.mega.pk/mobiles_products/24259/Viv...
# 4   4  https://www.mega.pk/mobiles_products/24204/App...
#
#                                                title  \
# 0  Nothing Phone 1 8GB RAM 256GB Storage Non PTA ...
# 1  Oppo F21 Pro 8GB Ram 128GB Storage 5G PTA Appr...
# 2                                    Tecno Spark 10
# 3                                       Vivo V27 5G
# 4                           Apple Iphone 15 Pro Max
#
#                                                 imgs  brand category   vendor  \
# 0  ['https://www.mega.pk/items_images/Nothing+Pho...    NaN   Mobile  MEGA.PK
# 1  ['https://www.mega.pk/items_images/Oppo+F21+Pr...   OPPO   Mobile  MEGA.PK
# 2  ['https://www.mega.pk/items_images/Tecno+Spark...  Tecno   Mobile  MEGA.PK
# 3  ['https://www.mega.pk/items_images/Vivo+V27+5G...   Vivo   Mobile  MEGA.PK
# 4  ['https://www.mega.pk/items_images/Apple+Iphon...  Apple   Mobile  MEGA.PK
#
#    used                                            address availability  ...  \
# 0     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...          NaN  ...
# 1     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...          NaN  ...
# 2     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
# 3     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
# 4     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
#
#                                       specifications  description  \
# 0  {'RAM': '8GB', 'Memory quantity': '', 'Interna...          NaN
# 1  {'RAM': '8gb', 'Memory quantity': '', 'Interna...          NaN
# 2  {'RAM': '4GB,8GB', 'Memory quantity': '', 'Int...          NaN
# 3  {'RAM': '8GB,12GB', 'Memory quantity': '', 'In...          NaN
# 4  {'RAM': '8GB', 'Memory quantity': '', 'Interna...          NaN
#
#    delivery_fee delivery_details warranty  warranty_type  average_rating  \
# 0           NaN              NaN      NaN            NaN             NaN
# 1           NaN              NaN      NaN            NaN             NaN
# 2           NaN              NaN   1 year            NaN             NaN
# 3           NaN              NaN   1 year            NaN             NaN
# 4           NaN              NaN      NaN            NaN             NaN
#
#   num_ratings reviews                                         clean_text
# 0         NaN      []  Nothing Phone 1 8GB RAM 256GB Storage Non PTA ...
# 1         NaN      []  Oppo F21 Pro 8GB Ram 128GB Storage 5G PTA Appr...
# 2         NaN      []  Tecno Spark 10  Tecno Mobile RAM:4GB,8GB Inter...
# 3         NaN      []  Vivo V27 5G  Vivo Mobile RAM:8GB,12GB Internal...
# 4         NaN      []  Apple Iphone 15 Pro Max  Apple Mobile RAM:8GB ...
#
# [5 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# id                     0
# slug                   0
# title                  0
# imgs                   0
# brand                893
# category               0
# vendor                 0
# used                   0
# address             1122
# availability         587
# currency               0
# original_price        17
# discounted_price     927
# specifications         0
# description         1367
# delivery_fee        1559
# delivery_details    1666
# warranty            1166
# warranty_type       1277
# average_rating       766
# num_ratings          766
# reviews                0
# clean_text             0
# dtype: int64

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
df['embeddings'] = df['clean_text'].apply(lambda x : model.encode(x))

# %%
df.head()
# Out:
#    id                                               slug  \
# 0   0  https://www.mega.pk/mobiles_products/23522/Not...
# 1   1  https://www.mega.pk/mobiles_products/23458/Opp...
# 2   2  https://www.mega.pk/mobiles_products/24393/Tec...
# 3   3  https://www.mega.pk/mobiles_products/24259/Viv...
# 4   4  https://www.mega.pk/mobiles_products/24204/App...
#
#                                                title  \
# 0  Nothing Phone 1 8GB RAM 256GB Storage Non PTA ...
# 1  Oppo F21 Pro 8GB Ram 128GB Storage 5G PTA Appr...
# 2                                    Tecno Spark 10
# 3                                       Vivo V27 5G
# 4                           Apple Iphone 15 Pro Max
#
#                                                 imgs  brand category   vendor  \
# 0  ['https://www.mega.pk/items_images/Nothing+Pho...    NaN   Mobile  MEGA.PK
# 1  ['https://www.mega.pk/items_images/Oppo+F21+Pr...   OPPO   Mobile  MEGA.PK
# 2  ['https://www.mega.pk/items_images/Tecno+Spark...  Tecno   Mobile  MEGA.PK
# 3  ['https://www.mega.pk/items_images/Vivo+V27+5G...   Vivo   Mobile  MEGA.PK
# 4  ['https://www.mega.pk/items_images/Apple+Iphon...  Apple   Mobile  MEGA.PK
#
#    used                                            address availability  ...  \
# 0     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...          NaN  ...
# 1     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...          NaN  ...
# 2     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
# 3     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
# 4     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...  Coming Soon  ...
#
#   description  delivery_fee  delivery_details warranty warranty_type  \
# 0         NaN           NaN               NaN      NaN           NaN
# 1         NaN           NaN               NaN      NaN           NaN
# 2         NaN           NaN               NaN   1 year           NaN
# 3         NaN           NaN               NaN   1 year           NaN
# 4         NaN           NaN               NaN      NaN           NaN
#
#    average_rating  num_ratings reviews  \
# 0             NaN          NaN      []
# 1             NaN          NaN      []
# 2             NaN          NaN      []
# 3             NaN          NaN      []
# 4             NaN          NaN      []
#
#                                           clean_text  \
# 0  Nothing Phone 1 8GB RAM 256GB Storage Non PTA ...
# 1  Oppo F21 Pro 8GB Ram 128GB Storage 5G PTA Appr...
# 2  Tecno Spark 10  Tecno Mobile RAM:4GB,8GB Inter...
# 3  Vivo V27 5G  Vivo Mobile RAM:8GB,12GB Internal...
# 4  Apple Iphone 15 Pro Max  Apple Mobile RAM:8GB ...
#
#                                           embeddings
# 0  [-0.031639054, 0.024927748, 0.059493024, -0.07...
# 1  [-0.02028133, 0.02233131, 0.01556493, -0.01725...
# 2  [-0.057045326, -0.048345394, -0.040879004, -0....
# 3  [-0.010266217, -0.039680757, 0.0074030417, -0....
# 4  [-0.0023281914, 0.0074312524, 0.043554112, -0....
#
# [5 rows x 24 columns]

# %%
df.to_pickle('product_embeddings.pkl')

df = pd.read_pickle('product_embeddings.pkl')

# %%
def recommended_products(query , top_k = 5):

  query = query.lower()
  query_embedding = model.encode(query)
  df['similarity'] = df['embeddings'].apply(lambda x : cosine_similarity([query_embedding] , [x]).flatten()[0])
  recommendations = df.sort_values(by='similarity' , ascending=False).head(top_k)
  return recommendations[['title' , 'brand' , 'category', 'similarity' , 'imgs']]

# %%
q = 'samsung galaxy s22 ultra'
recommended_products(q)
# Out:
#                                                   title    brand category  \
# 1382                           Samsung Galaxy S22 Ultra      NaN   Mobile
# 1429                                 Samsung Galaxy S22      NaN   Mobile
# 1534                           Samsung Galaxy S23 Ultra      NaN   Mobile
# 145   Samsung Galaxy S22 Ultra 12GB Ram 256GB Storag...  Samsung   Mobile
# 128   Samsung Galaxy S22 Ultra 12GB Ram 512GB Storag...  Samsung   Mobile
#
#       similarity                                               imgs
# 1382    0.745557  ['https://images.priceoye.pk/samsung-galaxy-s2...
# 1429    0.681177  ['https://images.priceoye.pk/samsung-galaxy-s2...
# 1534    0.673594  ['https://images.priceoye.pk/samsung-galaxy-s2...
# 145     0.654621  ['https://www.mega.pk/items_images/Samsung+Gal...
# 128     0.647524  ['https://www.mega.pk/items_images/Samsung+Gal...
